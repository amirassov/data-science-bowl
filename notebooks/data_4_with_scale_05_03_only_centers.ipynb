# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:95% !important; }</style>"))

# %%
import warnings
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FutureWarning)
warnings.simplefilter("ignore", RuntimeWarning)

import sys
sys.path.append('../../dstorch/')

import matplotlib.pyplot as plt
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from dstorch import preprocessing, io, draw
import os
import cv2

# %%
preprocessing_args = {
    'train_path': '../data/kaggle-dsbowl-2018-dataset-fixes/stage1_train/', 
    'extra_path': '../data/extra_data/extra_data/', 
    'output_path': '../output_data/with_scale_05_03_only_centers/',
    'distance_path': '../output_data/without_scale_05/distances/',
    'invert': True, 
    'center_thresholds': [0.5, 0.3], 
    'contour_thresholds': [], 
    'scale': True,
    'labels_file': "../output_data/train_extra_labels.csv", 
    'size': 250 
}

preprocessing.prepare_train_data(**preprocessing_args)
# Out:
# ...
# Scale & save train data: 100%|██████████| 694/694 [00:09<00:00, 72.77it/s]

# %%
name = '40b00d701695d8ea5d59f95ac39e18004040c96d17fbc1a539317c674eca084b.png'

draw.plots([
    cv2.imread('../output_data/with_scale_05_03_only_centers/scaled_images/{}'.format(name)),
    cv2.imread('../output_data/with_scale_05_03_only_centers/scaled_masks/{}'.format(name))[..., 0],
    cv2.imread('../output_data/with_scale_05_03_only_centers/scaled_masks/{}'.format(name))[..., 1],
    cv2.imread('../output_data/with_scale_05_03_only_centers/scaled_masks/{}'.format(name))[..., 2],
    cv2.imread('../output_data/with_scale_05_03_only_centers/distances/{}'.format(name)),
], col_number=5, scale=3)
